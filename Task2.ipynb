# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Task2.csv')

# %%
df
# Out:
#         Period       Revenue  Sales_quantity  Average_cost  \
# 0   01.01.2015  1.601007e+07         12729.0   1257.763541
# 1   01.02.2015  1.580759e+07         11636.0   1358.507000
# 2   01.03.2015  2.204715e+07         15922.0   1384.697024
# 3   01.04.2015  1.881458e+07         15227.0   1235.606705
# 4   01.05.2015  1.402148e+07          8620.0   1626.621765
# ..         ...           ...             ...           ...
# 91  01.08.2022           NaN             NaN           NaN
# 92  01.09.2022           NaN             NaN           NaN
# 93  01.10.2022           NaN             NaN           NaN
# 94  01.11.2022           NaN             NaN           NaN
# 95  01.12.2022           NaN             NaN           NaN
#
#     The_average_annual_payroll_of_the_region
# 0                                 30024676.0
# 1                                 30024676.0
# 2                                 30024676.0
# 3                                 30024676.0
# ...

# %%
df.isnull().sum()
# Out:
# Period                                       0
# Revenue                                     32
# Sales_quantity                              32
# Average_cost                                32
# The_average_annual_payroll_of_the_region    32
# dtype: int64

# %%
df.dropna()
# Out:
#        Period       Revenue  Sales_quantity  Average_cost  \
# 6  2015-01-07  1.916189e+07         17254.0   1110.576805
# 7  2015-01-08  1.520498e+07          8642.0   1759.428870
# 8  2015-01-09  2.060394e+07         16144.0   1276.259909
# 9  2015-01-10  2.099287e+07         18135.0   1157.588904
# 10 2015-01-11  1.499337e+07         10841.0   1383.024597
# 11 2015-01-12  2.779181e+07         22113.0   1256.808558
# 12 2016-01-01  2.860159e+07         15365.0   1861.476505
# 13 2016-01-02  2.236707e+07         13153.0   1700.530226
# 14 2016-01-03  2.973861e+07         18339.0   1621.604699
# 15 2016-01-04  2.835101e+07         13909.0   2038.321083
# 16 2016-01-05  1.526460e+07          8553.0   1784.707557
# 17 2016-01-06  2.438566e+07         15101.0   1614.837301
# 18 2016-01-07  2.948652e+07         15695.0   1878.720425
# 19 2016-01-08  1.527012e+07          8314.0   1836.675157
# 20 2016-01-09  3.614103e+07         17764.0   2034.509545
# ...

# %%
import matplotlib.pyplot as plt

# %%
time_column = 'Period'
value_column = 'Sales_quantity'

df[time_column] = pd.to_datetime(df[time_column])

plt.figure(figsize=(15,10))
plt.plot(df[time_column], df[value_column], marker='o', linestyle='-', color='blue')
plt.title(f'Trend Over Time: {value_column}')
plt.xlabel('Time')
plt.ylabel(value_column)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
time_column = 'Period'
value_column = 'Average_cost'  

# Convert the 'Date' column to datetime if it's not already
df[time_column] = pd.to_datetime(df[time_column])

# Calculate the moving average with a specified window size
window_size = 7  # Adjust the window size based on your preference
df['Moving_Average'] = df[value_column].rolling(window=window_size).mean()

# Plot the original values and the moving average
plt.figure(figsize=(15,10))
plt.plot(df[time_column], df[value_column], label='Original Values', marker='o', linestyle='-', color='blue')
plt.plot(df[time_column], df['Moving_Average'], label=f'Moving Average ({window_size} days)', linestyle='--', color='orange')
plt.title(f'Trend Over Time with Moving Average: {value_column}')
plt.xlabel('Time')
plt.ylabel(value_column)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
time_column = 'Period'
value_column = 'Sales_quantity'  

# Convert the 'Date' column to datetime if it's not already
df[time_column] = pd.to_datetime(df[time_column])

# Calculate the moving average with a specified window size
window_size = 7  # Adjust the window size based on your preference
df['Moving_Average'] = df[value_column].rolling(window=window_size).mean()

# Plot the original values and the moving average
plt.figure(figsize=(15,10))
plt.plot(df[time_column], df[value_column], label='Original Values', marker='o', linestyle='-', color='blue')
plt.plot(df[time_column], df['Moving_Average'], label=f'Moving Average ({window_size} days)', linestyle='--', color='orange')
plt.title(f'Trend Over Time with Moving Average: {value_column}')
plt.xlabel('Time')
plt.ylabel(value_column)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df.columns
# Out:
# Index(['Period', 'Revenue', 'Sales_quantity', 'Average_cost',
#        'The_average_annual_payroll_of_the_region', 'Moving_Average'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Revenue                                     32
# Sales_quantity                              32
# Average_cost                                32
# The_average_annual_payroll_of_the_region    32
# Moving_Average                              38
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#                  Revenue  Sales_quantity  Average_cost  \
# Period
# 2015-01-07  1.916189e+07         17254.0   1110.576805
# 2015-01-08  1.520498e+07          8642.0   1759.428870
# 2015-01-09  2.060394e+07         16144.0   1276.259909
# 2015-01-10  2.099287e+07         18135.0   1157.588904
# 2015-01-11  1.499337e+07         10841.0   1383.024597
# 2015-01-12  2.779181e+07         22113.0   1256.808558
# 2016-01-01  2.860159e+07         15365.0   1861.476505
# 2016-01-02  2.236707e+07         13153.0   1700.530226
# 2016-01-03  2.973861e+07         18339.0   1621.604699
# 2016-01-04  2.835101e+07         13909.0   2038.321083
# 2016-01-05  1.526460e+07          8553.0   1784.707557
# 2016-01-06  2.438566e+07         15101.0   1614.837301
# 2016-01-07  2.948652e+07         15695.0   1878.720425
# 2016-01-08  1.527012e+07          8314.0   1836.675157
# 2016-01-09  3.614103e+07         17764.0   2034.509545
# 2016-01-10  2.791514e+07         18969.0   1471.619150
# ...

# %%
columns_to_decompose = ['Revenue', 'Sales_quantity', 'Average_cost', 'The_average_annual_payroll_of_the_region']

# Apply seasonal decomposition for each column
for column in columns_to_decompose:
    result = seasonal_decompose(df[column], model='additive', period=1)  # Adjust the period based on your data

    # Plot the original time series, trend, seasonality, and residuals
    plt.figure(figsize=(12, 8))

    plt.subplot(4, 2, 1)
    plt.plot(df[column], label='Original Time Series')
    plt.legend()

    plt.subplot(4, 2, 2)
    plt.plot(result.trend, label='Trend')
    plt.legend()

    plt.subplot(4, 2, 3)
    plt.plot(result.seasonal, label='Seasonality')
    plt.legend()

    plt.subplot(4, 2, 4)
    plt.plot(result.resid, label='Residuals')
    plt.legend()

    plt.suptitle(f'Seasonal Decomposition of {column}')
    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %%
significant_events = {
    '2022-05-01': 'Labor Day Sale',
    '2022-12-25': 'Christmas Day',
    # Add more events and dates as needed
}

for date, event in significant_events.items():
    plt.axvline(x=pd.to_datetime(date), color='red', linestyle='--', linewidth=2, label=event)

plt.suptitle(f'Seasonal Decomposition of {column} with Annotations')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
